# %% [markdown]
# <a href="https://colab.research.google.com/github/makms2023/ds1002-ntr8qx/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

labels = labels
sections = slices
colors = ['c', 'g', 'y']

plt.pie(slices, labels=labels, autopct='%1.0f%%', startangle=90)

plt.axis('equal')
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n, bins=10)
plt.title("Histogram")
plt.show()

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(df['x'], df['y'], label='Data Points')

z = np.polyfit(df['x'], df['y'], 1)
p = np.poly1d(z)

plt.plot(x, p(x))
plt.scatter(x,y)

plt.show()
